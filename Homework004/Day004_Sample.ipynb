# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"14127796955","type":"PullRequestEvent","actor":{"id":5248597,"login":"sercero","display_login":"sercero","gravatar_id":"","url":"https://api.github.com/users/sercero","avatar_url":"https://avatars.githubusercontent.com/u/5248597?"},"repo":{"id":22758435,"name":"MyGUI/mygui","url":"https://api.github.com/repos/MyGUI/mygui"},"payload":{"action":"opened","number":193,"pull_request":{"url":"https://api.github.com/repos/MyGUI/mygui/pulls/193","id":517773182,"node_id":"MDExOlB1bGxSZXF1ZXN0NTE3NzczMTgy","html_url":"https://github.com/MyGUI/mygui/pull/193","diff_url":"https://github.com/MyGUI/mygui/pull/193.diff","patch_url":"https://github.com/MyGUI/mygui/pull/193.patch","issue_url":"https://api.github.com/repos/MyGUI/mygui/issues/193","number":193,"state":"open","locked":false,"title":"Fixes for DirectX9 OgrePlatform","user":{"login":"sercero","id":5248597,"node_id":"MDQ6VXNlcjUyNDg1OTc=","avatar_url":"https://avatars2.githubusercontent.com/u/5248597?v=4","gravatar_id":"","url":"https://api.github.com/users/sercero","html_url":"https://github.com/sercero","followers_url":"https://api.github.com/users/sercero/followers","following_url":"https://api.github.com/users/sercero/following{/other_user}","gists_url":"https://api.github.com/users/sercero/gists{/gist_id}","starred_url":"https://api.github.com/users/sercero/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/sercero/subscriptions","organizations_url":"https://api.github.com/users/sercero/orgs","repos_url":"https://api.github.com/users/sercero/repos","events_url":"https://api.github.com/users/sercero/events{/privacy}","received_events_url":"https://api.github.com/users/sercero/received_events","type":"User","site_admin":false},"body":"Applied fixes mentiones in the OGRE3D forums in order to have MyGUI working with latest OGRE version.\\r\\n[https://forums.ogre3d.org/viewtopic.php?f=2&t=95059](url)\\r\\n\\r\\nIssue #179 \\r\\n","created_at":"2020-11-09T13:41:28Z","updated_at":"2020-11-09T13:41:28Z","closed_at":null,"merged_at":null,"merge_commit_sha":null,"assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"draft":false,"commits_url":"https://api.github.com/repos/MyGUI/mygui/pulls/193/commits","review_comments_url":"https://api.github.com/repos/MyGUI/mygui/pulls/193/comments","review_comment_url":"https://api.github.com/repos/MyGUI/mygui/pulls/comments{/number}","comments_url":"https://api.github.com/repos/MyGUI/mygui/issues/193/comments","statuses_url":"https://api.github.com/repos/MyGUI/mygui/statuses/f82edd68e0bbe800232b0ae8dfa0e38b0a3941fd","head":{"label":"sercero:master","ref":"master","sha":"f82edd68e0bbe800232b0ae8dfa0e38b0a3941fd","user":{"login":"sercero","id":5248597,"node_id":"MDQ6VXNlcjUyNDg1OTc=","avatar_url":"https://avatars2.githubusercontent.com/u/5248597?v=4","gravatar_id":"","url":"https://api.github.com/users/sercero","html_url":"https://github.com/sercero","followers_url":"https://api.github.com/users/sercero/followers","following_url":"https://api.github.com/users/sercero/following{/other_user}","gists_url":"https://api.github.com/users/sercero/gists{/gist_id}","starred_url":"https://api.github.com/users/sercero/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/sercero/subscriptions","organizations_url":"https://api.github.com/users/sercero/orgs","repos_url":"https://api.github.com/users/sercero/repos","events_url":"https://api.github.com/users/sercero/events{/privacy}","received_events_url":"https://api.github.com/users/sercero/received_events","type":"User","site_admin":false},"repo":{"id":311341643,"node_id":"MDEwOlJlcG9zaXRvcnkzMTEzNDE2NDM=","name":"mygui","full_name":"sercero/mygui","private":false,"owner":{"login":"sercero","id":5248597,"node_id":"MDQ6VXNlcjUyNDg1OTc=","avatar_url":"https://avatars2.githubusercontent.com/u/5248597?v=4","gravatar_id":"","url":"https://api.github.com/users/sercero","html_url":"https://github.com/sercero","follower ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '14127796955',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 5248597,
#    'login': 'sercero',
#    'display_login': 'sercero',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sercero',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5248597?'},
#   'repo': {'id': 22758435,
#    'name': 'MyGUI/mygui',
#    'url': 'https://api.github.com/repos/MyGUI/mygui'},
#   'payload': {'action': 'opened',
#    'number': 193,
#    'pull_request': {'url': 'https://api.github.com/repos/MyGUI/mygui/pulls/193',
#     'id': 517773182,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NTE3NzczMTgy',
#     'html_url': 'https://github.com/MyGUI/mygui/pull/193',
#     'diff_url': 'https://github.com/MyGUI/mygui/pull/193.diff',
#     'patch_url': 'https://github.com/MyGUI/mygui/pull/193.patch',
#     'issue_url': 'https://api.github.com/repos/MyGUI/mygui/issues/193',
#     'number': 193,
#     'state': 'open',
#     'locked': False,
#     'title': 'Fixes for DirectX9 OgrePlatform',
#     'user': {'login': 'sercero',
#      'id': 5248597,
#      'node_id': 'MDQ6VXNlcjUyNDg1OTc=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/5248597?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/sercero',
#      'html_url': 'https://github.com/sercero',
#      'followers_url': 'https://api.github.com/users/sercero/followers',
#      'following_url': 'https://api.github.com/users/sercero/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/sercero/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/sercero/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/sercero/subscriptions',
#      'organizations_url': 'https://api.github.com/users/sercero/orgs',
#      'repos_url': 'https://api.github.com/users/sercero/repos',
#      'events_url': 'https://api.github.com/users/sercero/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/sercero/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Applied fixes mentiones in the OGRE3D forums in order to have MyGUI working with latest OGRE version.\r\n[https://forums.ogre3d.org/viewtopic.php?f=2&t=95059](url)\r\n\r\nIssue #179 \r\n',
#     'created_at': '2020-11-09T13:41:28Z',
#     'updated_at': '2020-11-09T13:41:28Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/MyGUI/mygui/pulls/193/commits',
#     'review_comments_url': 'https://api.github.com/repos/MyGUI/mygui/pulls/193/comments',
#     'review_comment_url': 'https://api.github.com/repos/MyGUI/mygui/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/MyGUI/mygui/issues/193/comments',
#     'statuses_url': 'https://api.github.com/repos/MyGUI/mygui/statuses/f82edd68e0bbe800232b0ae8dfa0e38b0a3941fd',
#     'head': {'label': 'sercero:master',
#      'ref': 'master',
#      'sha': 'f82edd68e0bbe800232b0ae8dfa0e38b0a3941fd',
#      'user': {'login': 'sercero',
#       'id': 5248597,
#       'node_id': 'MDQ6VXNlcjUyNDg1OTc=',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/5248597?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/sercero',
#       'html_url': 'https://github.com/sercero',
#       'followers_url': 'https://api.github.com/users/sercero/followers',
#       'following_url': 'https://api.github.com/users/sercero/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/sercero/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/sercero/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/sercero/subscriptions',
#       'organizations_url': 'https://api.github.com/users/sercero/orgs',
#       'repos_url': 'https://api.github.com/users/sercero/repos',
#       'events_url': 'https://api.github.com/users/sercero/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/sercero/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 311341643,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMTEzNDE2NDM=',
#       'name': 'mygui',
#       'full_name': 'sercero/mygui',
#       'private': False,
#       'owner': {'login': 'sercero',
#        'id': 5248597,
#        'node_id': 'MDQ6VXNlcjUyNDg1OTc=',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/5248597?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/sercero',
#        'html_url': 'https://github.com/sercero',
#        'followers_url': 'https://api.github.com/users/sercero/followers',
#        'following_url': 'https://api.github.com/users/sercero/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/sercero/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/sercero/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/sercero/subscriptions',
#        'organizations_url': 'https://api.github.com/users/sercero/orgs',
#        'repos_url': 'https://api.github.com/users/sercero/repos',
#        'events_url': 'https://api.github.com/users/sercero/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/sercero/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/sercero/mygui',
#       'description': 'Fast, flexible and simple GUI.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/sercero/mygui',
#       'forks_url': 'https://api.github.com/repos/sercero/mygui/forks',
#       'keys_url': 'https://api.github.com/repos/sercero/mygui/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/sercero/mygui/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/sercero/mygui/teams',
#       'hooks_url': 'https://api.github.com/repos/sercero/mygui/hooks',
#       'issue_events_url': 'https://api.github.com/repos/sercero/mygui/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/sercero/mygui/events',
#       'assignees_url': 'https://api.github.com/repos/sercero/mygui/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/sercero/mygui/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/sercero/mygui/tags',
#       'blobs_url': 'https://api.github.com/repos/sercero/mygui/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/sercero/mygui/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/sercero/mygui/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/sercero/mygui/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/sercero/mygui/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/sercero/mygui/languages',
#       'stargazers_url': 'https://api.github.com/repos/sercero/mygui/stargazers',
#       'contributors_url': 'https://api.github.com/repos/sercero/mygui/contributors',
#       'subscribers_url': 'https://api.github.com/repos/sercero/mygui/subscribers',
#       'subscription_url': 'https://api.github.com/repos/sercero/mygui/subscription',
#       'commits_url': 'https://api.github.com/repos/sercero/mygui/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/sercero/mygui/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/sercero/mygui/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/sercero/mygui/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/sercero/mygui/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/sercero/mygui/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/sercero/mygui/merges',
#       'archive_url': 'https://api.github.com/repos/sercero/mygui/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/sercero/mygui/downloads',
#       'issues_url': 'https://api.github.com/repos/sercero/mygui/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/sercero/mygui/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/sercero/mygui/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/sercero/mygui/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/sercero/mygui/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/sercero/mygui/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/sercero/mygui/deployments',
#       'created_at': '2020-11-09T13:08:06Z',
#       'updated_at': '2020-11-09T13:38:04Z',
#       'pushed_at': '2020-11-09T13:37:57Z',
#       'git_url': 'git://github.com/sercero/mygui.git',
#       'ssh_url': 'git@github.com:sercero/mygui.git',
#       'clone_url': 'https://github.com/sercero/mygui.git',
#       'svn_url': 'https://github.com/sercero/mygui',
#       'homepage': 'http://mygui.info/',
#       'size': 81098,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'C++',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'MyGUI:master',
#      'ref': 'master',
#      'sha': '6ff510345aa5ffc25cd699d797aabccb5d73bde2',
#      'user': {'login': 'MyGUI',
#       'id': 8388582,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjgzODg1ODI=',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/8388582?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/MyGUI',
#       'html_url': 'https://github.com/MyGUI',
#       'followers_url': 'https://api.github.com/users/MyGUI/followers',
#       'following_url': 'https://api.github.com/users/MyGUI/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/MyGUI/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/MyGUI/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/MyGUI/subscriptions',
#       'organizations_url': 'https://api.github.com/users/MyGUI/orgs',
#       'repos_url': 'https://api.github.com/users/MyGUI/repos',
#       'events_url': 'https://api.github.com/users/MyGUI/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/MyGUI/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 22758435,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjc1ODQzNQ==',
#       'name': 'mygui',
#       'full_name': 'MyGUI/mygui',
#       'private': False,
#       'owner': {'login': 'MyGUI',
#        'id': 8388582,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjgzODg1ODI=',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/8388582?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/MyGUI',
#        'html_url': 'https://github.com/MyGUI',
#        'followers_url': 'https://api.github.com/users/MyGUI/followers',
#        'following_url': 'https://api.github.com/users/MyGUI/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/MyGUI/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/MyGUI/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/MyGUI/subscriptions',
#        'organizations_url': 'https://api.github.com/users/MyGUI/orgs',
#        'repos_url': 'https://api.github.com/users/MyGUI/repos',
#        'events_url': 'https://api.github.com/users/MyGUI/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/MyGUI/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/MyGUI/mygui',
#       'description': 'Fast, flexible and simple GUI.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/MyGUI/mygui',
#       'forks_url': 'https://api.github.com/repos/MyGUI/mygui/forks',
#       'keys_url': 'https://api.github.com/repos/MyGUI/mygui/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/MyGUI/mygui/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/MyGUI/mygui/teams',
#       'hooks_url': 'https://api.github.com/repos/MyGUI/mygui/hooks',
#       'issue_events_url': 'https://api.github.com/repos/MyGUI/mygui/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/MyGUI/mygui/events',
#       'assignees_url': 'https://api.github.com/repos/MyGUI/mygui/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/MyGUI/mygui/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/MyGUI/mygui/tags',
#       'blobs_url': 'https://api.github.com/repos/MyGUI/mygui/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/MyGUI/mygui/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/MyGUI/mygui/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/MyGUI/mygui/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/MyGUI/mygui/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/MyGUI/mygui/languages',
#       'stargazers_url': 'https://api.github.com/repos/MyGUI/mygui/stargazers',
#       'contributors_url': 'https://api.github.com/repos/MyGUI/mygui/contributors',
#       'subscribers_url': 'https://api.github.com/repos/MyGUI/mygui/subscribers',
#       'subscription_url': 'https://api.github.com/repos/MyGUI/mygui/subscription',
#       'commits_url': 'https://api.github.com/repos/MyGUI/mygui/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/MyGUI/mygui/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/MyGUI/mygui/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/MyGUI/mygui/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/MyGUI/mygui/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/MyGUI/mygui/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/MyGUI/mygui/merges',
#       'archive_url': 'https://api.github.com/repos/MyGUI/mygui/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/MyGUI/mygui/downloads',
#       'issues_url': 'https://api.github.com/repos/MyGUI/mygui/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/MyGUI/mygui/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/MyGUI/mygui/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/MyGUI/mygui/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/MyGUI/mygui/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/MyGUI/mygui/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/MyGUI/mygui/deployments',
#       'created_at': '2014-08-08T13:22:46Z',
#       'updated_at': '2020-11-08T05:24:04Z',
#       'pushed_at': '2020-10-25T16:32:49Z',
#       'git_url': 'git://github.com/MyGUI/mygui.git',
#       'ssh_url': 'git@github.com:MyGUI/mygui.git',
#       'clone_url': 'https://github.com/MyGUI/mygui.git',
#       'svn_url': 'https://github.com/MyGUI/mygui',
#       'homepage': 'http://mygui.info/',
#       'size': 81098,
#       'stargazers_count': 500,
#       'watchers_count': 500,
#       'language': 'C++',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 173,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 23,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 173,
#       'open_issues': 23,
#       'watchers': 500,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/MyGUI/mygui/pulls/193'},
#      'html': {'href': 'https://github.com/MyGUI/mygui/pull/193'},
#      'issue': {'href': 'https://api.github.com/repos/MyGUI/mygui/issues/193'},
#      'comments': {'href': 'https://api.github.com/repos/MyGUI/mygui/issues/193/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/MyGUI/mygui/pulls/193/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/MyGUI/mygui/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/MyGUI/mygui/pulls/193/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/MyGUI/mygui/statuses/f82edd68e0bbe800232b0ae8dfa0e38b0a3941fd'}},
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 3,
#     'additions': 8,
#     'deletions': 8,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2020-11-09T13:41:28Z',
#   'org': {'id': 8388582,
#    'login': 'MyGUI',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/MyGUI',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8388582?'}},
#  {'id': '14127796947',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 265903,
#    'login': 'alexnask',
#    'display_login': 'alexnask',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alexnask',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/265903?'},
#   'repo': {'id': 40276274,
#    'name': 'ziglang/zig',
#    'url': 'https://api.github.com/repos/ziglang/zig'},
#   'payload': {'action': 'closed',
#    'number': 7023,
#    'pull_request': {'url': 'https://api.github.com/repos/ziglang/zig/pulls/7023',
#     'id': 517189868,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NTE3MTg5ODY4',
#     'html_url': 'https://github.com/ziglang/zig/pull/7023',
#     'diff_url': 'https://github.com/ziglang/zig/pull/7023.diff',
#     'patch_url': 'https://github.com/ziglang/zig/pull/7023.patch',
#     'issue_url': 'https://api.github.com/repos/ziglang/zig/issues/7023',
#     'number': 7023,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Temporarily disable the cache for zig cc in link mode',
#     'user': {'login': 'jedisct1',
#      'id': 124872,
#      'node_id': 'MDQ6VXNlcjEyNDg3Mg==',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/124872?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jedisct1',
#      'html_url': 'https://github.com/jedisct1',
#      'followers_url': 'https://api.github.com/users/jedisct1/followers',
#      'following_url': 'https://api.github.com/users/jedisct1/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jedisct1/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jedisct1/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jedisct1/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jedisct1/orgs',
#      'repos_url': 'https://api.github.com/users/jedisct1/repos',
#      'events_url': 'https://api.github.com/users/jedisct1/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jedisct1/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "`zig cc` cannot be really used any more (see #6979) due to caching issues:\r\n\r\n```sh\r\n$ rm -fr zig-cache\r\n$ zig cc -o test test.c\r\n$ zig cc -o test2 test.c\r\nattempt to unwrap error: FileNotFound\r\n$ zig cc test.c\r\nattempt to unwrap error: FileNotFound\r\n```\r\n\r\nThis PR disables the cache for the link operation when using `zig cc`. It doesn't fix the root cause and it is a terrible, horrible, awful thing to do. But since we are getting so close to the 0.7.0 release, maybe that can be a last resort option in order to avoid shipping the release with that issue.",
#     'created_at': '2020-11-07T20:42:25Z',
#     'updated_at': '2020-11-09T13:41:28Z',
#     'closed_at': '2020-11-09T13:41:27Z',
#     'merged_at': None,
#     'merge_commit_sha': 'c791ef7e6b08b4e516d3af0fbbbe07191ba46b5a',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': {'url': 'https://api.github.com/repos/ziglang/zig/milestones/10',
#      'html_url': 'https://github.com/ziglang/zig/milestone/10',
#      'labels_url': 'https://api.github.com/repos/ziglang/zig/milestones/10/labels',
#      'id': 5304103,
#      'node_id': 'MDk6TWlsZXN0b25lNTMwNDEwMw==',
#      'number': 10,
#      'title': '0.8.0',
#      'description': 'Accept and resolve these issues, reject, or postpone them before releasing 0.8.0.',
#      'creator': {'login': 'andrewrk',
#       'id': 106511,
#       'node_id': 'MDQ6VXNlcjEwNjUxMQ==',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/106511?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/andrewrk',
#       'html_url': 'https://github.com/andrewrk',
#       'followers_url': 'https://api.github.com/users/andrewrk/followers',
#       'following_url': 'https://api.github.com/users/andrewrk/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/andrewrk/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/andrewrk/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/andrewrk/subscriptions',
#       'organizations_url': 'https://api.github.com/users/andrewrk/orgs',
#       'repos_url': 'https://api.github.com/users/andrewrk/repos',
#       'events_url': 'https://api.github.com/users/andrewrk/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/andrewrk/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 623,
#      'closed_issues': 1,
#      'state': 'open',
#      'created_at': '2020-04-13T17:41:37Z',
#      'updated_at': '2020-11-09T13:41:27Z',
#      'due_on': '2021-07-05T07:00:00Z',
#      'closed_at': None},
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/ziglang/zig/pulls/7023/commits',
#     'review_comments_url': 'https://api.github.com/repos/ziglang/zig/pulls/7023/comments',
#     'review_comment_url': 'https://api.github.com/repos/ziglang/zig/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/ziglang/zig/issues/7023/comments',
#     'statuses_url': 'https://api.github.com/repos/ziglang/zig/statuses/4cb70c1cd3b3e5d681d59c017b9ddc8bebb0d28e',
#     'head': {'label': 'jedisct1:zig-cc-disable-link-cache',
#      'ref': 'zig-cc-disable-link-cache',
#      'sha': '4cb70c1cd3b3e5d681d59c017b9ddc8bebb0d28e',
#      'user': {'login': 'jedisct1',
#       'id': 124872,
#       'node_id': 'MDQ6VXNlcjEyNDg3Mg==',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/124872?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jedisct1',
#       'html_url': 'https://github.com/jedisct1',
#       'followers_url': 'https://api.github.com/users/jedisct1/followers',
#       'following_url': 'https://api.github.com/users/jedisct1/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jedisct1/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jedisct1/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jedisct1/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jedisct1/orgs',
#       'repos_url': 'https://api.github.com/users/jedisct1/repos',
#       'events_url': 'https://api.github.com/users/jedisct1/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jedisct1/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 287523898,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyODc1MjM4OTg=',
#       'name': 'zig',
#       'full_name': 'jedisct1/zig',
#       'private': False,
#       'owner': {'login': 'jedisct1',
#        'id': 124872,
#        'node_id': 'MDQ6VXNlcjEyNDg3Mg==',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/124872?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/jedisct1',
#        'html_url': 'https://github.com/jedisct1',
#        'followers_url': 'https://api.github.com/users/jedisct1/followers',
#        'following_url': 'https://api.github.com/users/jedisct1/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jedisct1/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/jedisct1/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jedisct1/subscriptions',
#        'organizations_url': 'https://api.github.com/users/jedisct1/orgs',
#        'repos_url': 'https://api.github.com/users/jedisct1/repos',
#        'events_url': 'https://api.github.com/users/jedisct1/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/jedisct1/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/jedisct1/zig',
#       'description': 'General-purpose programming language and toolchain for maintaining robust, optimal, and reusable software.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/jedisct1/zig',
#       'forks_url': 'https://api.github.com/repos/jedisct1/zig/forks',
#       'keys_url': 'https://api.github.com/repos/jedisct1/zig/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/jedisct1/zig/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/jedisct1/zig/teams',
#       'hooks_url': 'https://api.github.com/repos/jedisct1/zig/hooks',
#       'issue_events_url': 'https://api.github.com/repos/jedisct1/zig/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/jedisct1/zig/events',
#       'assignees_url': 'https://api.github.com/repos/jedisct1/zig/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/jedisct1/zig/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/jedisct1/zig/tags',
#       'blobs_url': 'https://api.github.com/repos/jedisct1/zig/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jedisct1/zig/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jedisct1/zig/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/jedisct1/zig/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/jedisct1/zig/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jedisct1/zig/languages',
#       'stargazers_url': 'https://api.github.com/repos/jedisct1/zig/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jedisct1/zig/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jedisct1/zig/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jedisct1/zig/subscription',
#       'commits_url': 'https://api.github.com/repos/jedisct1/zig/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jedisct1/zig/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jedisct1/zig/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jedisct1/zig/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jedisct1/zig/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jedisct1/zig/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jedisct1/zig/merges',
#       'archive_url': 'https://api.github.com/repos/jedisct1/zig/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jedisct1/zig/downloads',
#       'issues_url': 'https://api.github.com/repos/jedisct1/zig/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jedisct1/zig/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jedisct1/zig/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jedisct1/zig/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jedisct1/zig/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jedisct1/zig/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jedisct1/zig/deployments',
#       'created_at': '2020-08-14T12:07:05Z',
#       'updated_at': '2020-11-08T22:59:40Z',
#       'pushed_at': '2020-11-08T22:59:50Z',
#       'git_url': 'git://github.com/jedisct1/zig.git',
#       'ssh_url': 'git@github.com:jedisct1/zig.git',
#       'clone_url': 'https://github.com/jedisct1/zig.git',
#       'svn_url': 'https://github.com/jedisct1/zig',
#       'homepage': 'https://ziglang.org',
#       'size': 99495,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'Zig',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     'base': {'label': 'ziglang:master',
#      'ref': 'master',
#      'sha': '03ae77b8b02eef4da09a6b0de12d6fb0192b81d4',
#      'user': {'login': 'ziglang',
#       'id': 27973237,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI3OTczMjM3',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/27973237?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ziglang',
#       'html_url': 'https://github.com/ziglang',
#       'followers_url': 'https://api.github.com/users/ziglang/followers',
#       'following_url': 'https://api.github.com/users/ziglang/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ziglang/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ziglang/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ziglang/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ziglang/orgs',
#       'repos_url': 'https://api.github.com/users/ziglang/repos',
#       'events_url': 'https://api.github.com/users/ziglang/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ziglang/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 40276274,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk0MDI3NjI3NA==',
#       'name': 'zig',
#       'full_name': 'ziglang/zig',
#       'private': False,
#       'owner': {'login': 'ziglang',
#        'id': 27973237,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI3OTczMjM3',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/27973237?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ziglang',
#        'html_url': 'https://github.com/ziglang',
#        'followers_url': 'https://api.github.com/users/ziglang/followers',
#        'following_url': 'https://api.github.com/users/ziglang/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ziglang/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ziglang/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ziglang/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ziglang/orgs',
#        'repos_url': 'https://api.github.com/users/ziglang/repos',
#        'events_url': 'https://api.github.com/users/ziglang/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ziglang/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/ziglang/zig',
#       'description': 'General-purpose programming language and toolchain for maintaining robust, optimal, and reusable software.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ziglang/zig',
#       'forks_url': 'https://api.github.com/repos/ziglang/zig/forks',
#       'keys_url': 'https://api.github.com/repos/ziglang/zig/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ziglang/zig/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ziglang/zig/teams',
#       'hooks_url': 'https://api.github.com/repos/ziglang/zig/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ziglang/zig/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ziglang/zig/events',
#       'assignees_url': 'https://api.github.com/repos/ziglang/zig/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ziglang/zig/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ziglang/zig/tags',
#       'blobs_url': 'https://api.github.com/repos/ziglang/zig/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ziglang/zig/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ziglang/zig/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ziglang/zig/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ziglang/zig/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ziglang/zig/languages',
#       'stargazers_url': 'https://api.github.com/repos/ziglang/zig/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ziglang/zig/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ziglang/zig/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ziglang/zig/subscription',
#       'commits_url': 'https://api.github.com/repos/ziglang/zig/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ziglang/zig/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ziglang/zig/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ziglang/zig/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ziglang/zig/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ziglang/zig/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ziglang/zig/merges',
#       'archive_url': 'https://api.github.com/repos/ziglang/zig/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ziglang/zig/downloads',
#       'issues_url': 'https://api.github.com/repos/ziglang/zig/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ziglang/zig/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ziglang/zig/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ziglang/zig/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ziglang/zig/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ziglang/zig/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ziglang/zig/deployments',
#       'created_at': '2015-08-06T00:51:28Z',
#       'updated_at': '2020-11-09T10:47:48Z',
#       'pushed_at': '2020-11-09T13:41:10Z',
#       'git_url': 'git://github.com/ziglang/zig.git',
#       'ssh_url': 'git@github.com:ziglang/zig.git',
#       'clone_url': 'https://github.com/ziglang/zig.git',
#       'svn_url': 'https://github.com/ziglang/zig',
#       'homepage': 'https://ziglang.org',
#       'size': 99983,
#       'stargazers_count': 7164,
#       'watchers_count': 7164,
#       'language': 'Zig',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 598,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1455,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 598,
#       'open_issues': 1455,
#       'watchers': 7164,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/ziglang/zig/pulls/7023'},
#      'html': {'href': 'https://github.com/ziglang/zig/pull/7023'},
#      'issue': {'href': 'https://api.github.com/repos/ziglang/zig/issues/7023'},
#      'comments': {'href': 'https://api.github.com/repos/ziglang/zig/issues/7023/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/ziglang/zig/pulls/7023/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/ziglang/zig/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/ziglang/zig/pulls/7023/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/ziglang/zig/statuses/4cb70c1cd3b3e5d681d59c017b9ddc8bebb0d28e'}},
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': False,
#     'mergeable_state': 'unstable',
#     'merged_by': None,
#     'comments': 2,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-11-09T13:41:28Z',
#   'org': {'id': 27973237,
#    'login': 'ziglang',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ziglang',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27973237?'}},
#  {'id': '14127796934',
#   'type': 'PushEvent',
#   'actor': {'id': 39814207,
#    'login': 'pull[bot]',
#    'display_login': 'pull',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pull[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?'},
#   'repo': {'id': 125673033,
#    'name': 'Pandinosaurus/three.js',
#    'url': 'https://api.github.com/repos/Pandinosaurus/three.js'},
#   'payload': {'push_id': 5998538992,
#    'size': 4,
#    'distinct_size': 4,
#    'ref': 'refs/heads/dev',
#    'head': '3a13bf40476cb7d00b54724198d03b3492cfde94',
#    'before': 'e4629dd3df9b72115b332406a36c56f6f6d1286e',
#    'commits': [{'sha': 'ae46dc9babbed8fecffc346e6630ec319a195b2e',
#      'author': {'email': 'michael.herzog@human-interactive.org',
#       'name': 'Mugen87'},
#      'message': 'Examples: Clean up.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Pandinosaurus/three.js/commits/ae46dc9babbed8fecffc346e6630ec319a195b2e'},
#     {'sha': '90594077618e30e67e9eaa399bb30965f0b32619',
#      'author': {'email': 'michael.herzog@human-interactive.org',
#       'name': 'Michael Herzog'},
#      'message': 'Merge pull request #20650 from Mugen87/dev51\n\nExamples: Clean up.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Pandinosaurus/three.js/commits/90594077618e30e67e9eaa399bb30965f0b32619'},
#     {'sha': '55523f2ebb6068e20530a5eb4e8a5c918ce7d876',
#      'author': {'email': 'michael.herzog@human-interactive.org',
#       'name': 'Mugen87'},
#      'message': 'Examples: More clean up.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Pandinosaurus/three.js/commits/55523f2ebb6068e20530a5eb4e8a5c918ce7d876'},
#     {'sha': '3a13bf40476cb7d00b54724198d03b3492cfde94',
#      'author': {'email': 'michael.herzog@human-interactive.org',
#       'name': 'Michael Herzog'},
#      'message': 'Merge pull request #20652 from Mugen87/dev51\n\nExamples: More clean up.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Pandinosaurus/three.js/commits/3a13bf40476cb7d00b54724198d03b3492cfde94'}]},
#   'public': True,
#   'created_at': '2020-11-09T13:41:28Z'},
#  {'id': '14127796941',
#   'type': 'ForkEvent',
#   'actor': {'id': 59569242,
#    'login': 'florianpasteur',
#    'display_login': 'florianpasteur',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/florianpasteur',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59569242?'},
#   'repo': {'id': 104471422,
#    'name': 'sibiraj-s/ngx-editor',
#    'url': 'https://api.github.com/repos/sibiraj-s/ngx-editor'},
#   'payload': {'forkee': {'id': 311350896,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkzMTEzNTA4OTY=',
#     'name': 'ngx-editor',
#     'full_name': 'florianpasteur/ngx-editor',
#     'private': False,
#     'owner': {'login': 'florianpasteur',
#      'id': 59569242,
#      'node_id': 'MDQ6VXNlcjU5NTY5MjQy',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/59569242?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/florianpasteur',
#      'html_url': 'https://github.com/florianpasteur',
#      'followers_url': 'https://api.github.com/users/florianpasteur/followers',
#      'following_url': 'https://api.github.com/users/florianpasteur/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/florianpasteur/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/florianpasteur/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/florianpasteur/subscriptions',
#      'organizations_url': 'https://api.github.com/users/florianpasteur/orgs',
#      'repos_url': 'https://api.github.com/users/florianpasteur/repos',
#      'events_url': 'https://api.github.com/users/florianpasteur/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/florianpasteur/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/florianpasteur/ngx-editor',
#     'description': '🖋️ A Simple WYSIWYG Editor for Angular Apps.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/florianpasteur/ngx-editor',
#     'forks_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/forks',
#     'keys_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/teams',
#     'hooks_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/hooks',
#     'issue_events_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/events',
#     'assignees_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/tags',
#     'blobs_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/languages',
#     'stargazers_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/stargazers',
#     'contributors_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/contributors',
#     'subscribers_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/subscribers',
#     'subscription_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/subscription',
#     'commits_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/merges',
#     'archive_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/downloads',
#     'issues_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/florianpasteur/ngx-editor/deployments',
#     'created_at': '2020-11-09T13:41:27Z',
#     'updated_at': '2020-11-05T10:00:30Z',
#     'pushed_at': '2020-10-28T07:35:09Z',
#     'git_url': 'git://github.com/florianpasteur/ngx-editor.git',
#     'ssh_url': 'git@github.com:florianpasteur/ngx-editor.git',
#     'clone_url': 'https://github.com/florianpasteur/ngx-editor.git',
#     'svn_url': 'https://github.com/florianpasteur/ngx-editor',
#     'homepage': 'https://sibiraj.dev/ngx-editor/',
#     'size': 6815,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': False,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-11-09T13:41:28Z'},
#  {'id': '14127796933',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 69338146,
#    'login': 'shixiaofeng7633',
#    'display_login': 'shixiaofeng7633',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shixiaofeng7633',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/69338146?'},
#   'repo': {'id': 310964532,
#    'name': 'shixiaofeng7633/visionwebsite',
#    'url': 'https://api.github.com/repos/shixiaofeng7633/visionwebsite'},
#   'payload': {'action': 'closed',
#    'number': 1,
#    'pull_request': {'url': 'https://api.github.com/repos/shixiaofeng7633/visionwebsite/pulls/1',
#     'id': 517772733,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NTE3NzcyNzMz',
#     'html_url': 'https://github.com/shixiaofeng7633/visionwebsite/pull/1',
#     'diff_url': 'https://github.com/shixiaofeng7633/visionwebsite/pull/1.diff',
#     'patch_url': 'https://github.com/shixiaofeng7633/visionwebsite/pull/1.patch',
#     'issue_url': 'https://api.github.com/repos/shixiaofeng7633/visionwebsite/issues/1',
#     'number': 1,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Bump bootstrap from 3.0.0 to 3.4.1 in /Application/SampleWebApplication',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
# ...
#       'created_at': '2020-10-24T18:35:22Z',
#       'updated_at': '2020-11-09T10:35:39Z',
#       'pushed_at': '2020-11-09T10:35:36Z',
#       'git_url': 'git://github.com/jiangjj/scripts.git',
#       'ssh_url': 'git@github.com:jiangjj/scripts.git',
#       'clone_url': 'https://github.com/jiangjj/scripts.git',
#       'svn_url': 'https://github.com/jiangjj/scripts',
#       'homepage': '',
#       'size': 6058,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'JavaScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/jiangjj/scripts/pulls/64'},
#      'html': {'href': 'https://github.com/jiangjj/scripts/pull/64'},
#      'issue': {'href': 'https://api.github.com/repos/jiangjj/scripts/issues/64'},
#      'comments': {'href': 'https://api.github.com/repos/jiangjj/scripts/issues/64/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/jiangjj/scripts/pulls/64/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/jiangjj/scripts/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/jiangjj/scripts/pulls/64/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/jiangjj/scripts/statuses/91718f4a3c7497f0b46099bb4c9ce68f4b594035'}},
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 2,
#     'additions': 2,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-11-09T13:41:28Z'},
#  {'id': '14127796839',
#   'type': 'CreateEvent',
#   'actor': {'id': 30853374,
#    'login': 'dhananjay4058',
#    'display_login': 'dhananjay4058',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dhananjay4058',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30853374?'},
#   'repo': {'id': 311350884,
#    'name': 'dhananjay4058/mbrdi-assignment',
#    'url': 'https://api.github.com/repos/dhananjay4058/mbrdi-assignment'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-11-09T13:41:28Z'},
#  {'id': '14127796838',
#   'type': 'IssuesEvent',
#   'actor': {'id': 4068610,
#    'login': 'ikedaosushi',
#    'display_login': 'ikedaosushi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ikedaosushi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4068610?'},
#   'repo': {'id': 121026767,
#    'name': 'ikedaosushi/tech-news',
#    'url': 'https://api.github.com/repos/ikedaosushi/tech-news'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/ikedaosushi/tech-news/issues/28610',
#     'repository_url': 'https://api.github.com/repos/ikedaosushi/tech-news',
#     'labels_url': 'https://api.github.com/repos/ikedaosushi/tech-news/issues/28610/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/ikedaosushi/tech-news/issues/28610/comments',
#     'events_url': 'https://api.github.com/repos/ikedaosushi/tech-news/issues/28610/events',
#     'html_url': 'https://github.com/ikedaosushi/tech-news/issues/28610',
#     'id': 739039127,
#     'node_id': 'MDU6SXNzdWU3MzkwMzkxMjc=',
#     'number': 28610,
#     'title': 'PyMC: Theano Is Dead Long Live Theano',
#     'user': {'login': 'ikedaosushi',
#      'id': 4068610,
#      'node_id': 'MDQ6VXNlcjQwNjg2MTA=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/4068610?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ikedaosushi',
#      'html_url': 'https://github.com/ikedaosushi',
#      'followers_url': 'https://api.github.com/users/ikedaosushi/followers',
#      'following_url': 'https://api.github.com/users/ikedaosushi/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ikedaosushi/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ikedaosushi/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ikedaosushi/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ikedaosushi/orgs',
#      'repos_url': 'https://api.github.com/users/ikedaosushi/repos',
#      'events_url': 'https://api.github.com/users/ikedaosushi/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ikedaosushi/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-11-09T13:41:27Z',
#     'updated_at': '2020-11-09T13:41:27Z',
#     'closed_at': None,
#     'author_association': 'OWNER',
#     'active_lock_reason': None,
#     'body': 'PyMC: Theano Is Dead, Long Live Theano<br>\n<br>\nhttps://ift.tt/2TnKIr4',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2020-11-09T13:41:28Z'},
#  {'id': '14127796834',
#   'type': 'CreateEvent',
#   'actor': {'id': 5042883,
#    'login': 'davidlange6',
#    'display_login': 'davidlange6',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/davidlange6',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5042883?'},
#   'repo': {'id': 311350813,
#    'name': 'compiler-research/clad',
#    'url': 'https://api.github.com/repos/compiler-research/clad'},
#   'payload': {'ref': 'fix-cxxmodules',
#    'ref_type': 'branch',
#    'master_branch': 'add-gcc7',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-11-09T13:41:28Z',
#   'org': {'id': 60820506,
#    'login': 'compiler-research',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/compiler-research',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60820506?'}},
#  {'id': '14127796817',
#   'type': 'DeleteEvent',
#   'actor': {'id': 42860905,
#    'login': 'DG1202',
#    'display_login': 'DG1202',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DG1202',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42860905?'},
#   'repo': {'id': 165292138,
#    'name': 'apache/incubator-datalab',
#    'url': 'https://api.github.com/repos/apache/incubator-datalab'},
#   'payload': {'ref': 'DATALAB-2149',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-11-09T13:41:28Z',
#   'org': {'id': 47359,
#    'login': 'apache',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/apache',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47359?'}},
#  {'id': '14127796802',
#   'type': 'PushEvent',
#   'actor': {'id': 74055815,
#    'login': 'kuniyu',
#    'display_login': 'kuniyu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kuniyu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74055815?'},
#   'repo': {'id': 310952719,
#    'name': 'kuniyu/git-app',
#    'url': 'https://api.github.com/repos/kuniyu/git-app'},
#   'payload': {'push_id': 5998538927,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/投稿画面作成',
#    'head': 'e47e51e16af7e31389120444060d9dcef80b9c36',
#    'before': '287174547edc3240a947712519c6bc960646515c',
#    'commits': [{'sha': 'e47e51e16af7e31389120444060d9dcef80b9c36',
#      'author': {'email': 'kuni10ura@gmail.com', 'name': 'kuniyu'},
#      'message': 'Update index.html.erb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kuniyu/git-app/commits/e47e51e16af7e31389120444060d9dcef80b9c36'}]},
#   'public': True,
#   'created_at': '2020-11-09T13:41:28Z'},
#  {'id': '14127796820',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 265903,
#    'login': 'alexnask',
#    'display_login': 'alexnask',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alexnask',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/265903?'},
#   'repo': {'id': 40276274,
#    'name': 'ziglang/zig',
#    'url': 'https://api.github.com/repos/ziglang/zig'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/ziglang/zig/issues/7023',
#     'repository_url': 'https://api.github.com/repos/ziglang/zig',
#     'labels_url': 'https://api.github.com/repos/ziglang/zig/issues/7023/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/ziglang/zig/issues/7023/comments',
#     'events_url': 'https://api.github.com/repos/ziglang/zig/issues/7023/events',
#     'html_url': 'https://github.com/ziglang/zig/pull/7023',
#     'id': 738314596,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NTE3MTg5ODY4',
#     'number': 7023,
#     'title': 'Temporarily disable the cache for zig cc in link mode',
#     'user': {'login': 'jedisct1',
#      'id': 124872,
#      'node_id': 'MDQ6VXNlcjEyNDg3Mg==',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/124872?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jedisct1',
#      'html_url': 'https://github.com/jedisct1',
#      'followers_url': 'https://api.github.com/users/jedisct1/followers',
#      'following_url': 'https://api.github.com/users/jedisct1/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jedisct1/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jedisct1/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jedisct1/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jedisct1/orgs',
#      'repos_url': 'https://api.github.com/users/jedisct1/repos',
#      'events_url': 'https://api.github.com/users/jedisct1/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jedisct1/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': {'url': 'https://api.github.com/repos/ziglang/zig/milestones/10',
#      'html_url': 'https://github.com/ziglang/zig/milestone/10',
#      'labels_url': 'https://api.github.com/repos/ziglang/zig/milestones/10/labels',
#      'id': 5304103,
#      'node_id': 'MDk6TWlsZXN0b25lNTMwNDEwMw==',
#      'number': 10,
#      'title': '0.8.0',
#      'description': 'Accept and resolve these issues, reject, or postpone them before releasing 0.8.0.',
#      'creator': {'login': 'andrewrk',
#       'id': 106511,
#       'node_id': 'MDQ6VXNlcjEwNjUxMQ==',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/106511?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/andrewrk',
#       'html_url': 'https://github.com/andrewrk',
#       'followers_url': 'https://api.github.com/users/andrewrk/followers',
#       'following_url': 'https://api.github.com/users/andrewrk/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/andrewrk/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/andrewrk/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/andrewrk/subscriptions',
#       'organizations_url': 'https://api.github.com/users/andrewrk/orgs',
#       'repos_url': 'https://api.github.com/users/andrewrk/repos',
#       'events_url': 'https://api.github.com/users/andrewrk/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/andrewrk/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 623,
#      'closed_issues': 1,
#      'state': 'open',
#      'created_at': '2020-04-13T17:41:37Z',
#      'updated_at': '2020-11-09T13:41:27Z',
#      'due_on': '2021-07-05T07:00:00Z',
#      'closed_at': None},
#     'comments': 1,
#     'created_at': '2020-11-07T20:42:25Z',
#     'updated_at': '2020-11-09T13:41:27Z',
#     'closed_at': '2020-11-09T13:41:27Z',
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/ziglang/zig/pulls/7023',
#      'html_url': 'https://github.com/ziglang/zig/pull/7023',
#      'diff_url': 'https://github.com/ziglang/zig/pull/7023.diff',
#      'patch_url': 'https://github.com/ziglang/zig/pull/7023.patch'},
#     'body': "`zig cc` cannot be really used any more (see #6979) due to caching issues:\r\n\r\n```sh\r\n$ rm -fr zig-cache\r\n$ zig cc -o test test.c\r\n$ zig cc -o test2 test.c\r\nattempt to unwrap error: FileNotFound\r\n$ zig cc test.c\r\nattempt to unwrap error: FileNotFound\r\n```\r\n\r\nThis PR disables the cache for the link operation when using `zig cc`. It doesn't fix the root cause and it is a terrible, horrible, awful thing to do. But since we are getting so close to the 0.7.0 release, maybe that can be a last resort option in order to avoid shipping the release with that issue.",
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/ziglang/zig/issues/comments/724020470',
#     'html_url': 'https://github.com/ziglang/zig/pull/7023#issuecomment-724020470',
#     'issue_url': 'https://api.github.com/repos/ziglang/zig/issues/7023',
#     'id': 724020470,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDcyNDAyMDQ3MA==',
#     'user': {'login': 'alexnask',
#      'id': 265903,
#      'node_id': 'MDQ6VXNlcjI2NTkwMw==',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/265903?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/alexnask',
#      'html_url': 'https://github.com/alexnask',
#      'followers_url': 'https://api.github.com/users/alexnask/followers',
#      'following_url': 'https://api.github.com/users/alexnask/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/alexnask/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/alexnask/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/alexnask/subscriptions',
#      'organizations_url': 'https://api.github.com/users/alexnask/orgs',
#      'repos_url': 'https://api.github.com/users/alexnask/repos',
#      'events_url': 'https://api.github.com/users/alexnask/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/alexnask/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-11-09T13:41:27Z',
#     'updated_at': '2020-11-09T13:41:27Z',
#     'author_association': 'MEMBER',
#     'body': 'Opened a new PR to fix this bug, #7036',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2020-11-09T13:41:28Z',
#   'org': {'id': 27973237,
#    'login': 'ziglang',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ziglang',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27973237?'}},
#  {'id': '14127796789',
#   'type': 'PushEvent',
#   'actor': {'id': 24195741,
#    'login': 'malgwi',
#    'display_login': 'malgwi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/malgwi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24195741?'},
#   'repo': {'id': 311341539,
#    'name': 'malgwi/news_app',
#    'url': 'https://api.github.com/repos/malgwi/news_app'},
#   'payload': {'push_id': 5998538918,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'a111345ae674f1f937172da3f820324ecc2441ed',
#    'before': '24c5d7f816e048fd0a76c4b37cbd1beb0c4e143d',
#    'commits': [{'sha': 'a111345ae674f1f937172da3f820324ecc2441ed',
#      'author': {'email': 'malgwisunday@gmail.com', 'name': 'malgwi'},
#      'message': 'minor refactoring',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/malgwi/news_app/commits/a111345ae674f1f937172da3f820324ecc2441ed'}]},
#   'public': True,
#   'created_at': '2020-11-09T13:41:28Z'}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.23.0',
#   'X-Amzn-Trace-Id': 'Root=1-5fa94837-439e84ea7cf189bb16c7bf31'},
#  'origin': '118.150.172.83',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.23.0',
#   'X-Amzn-Trace-Id': 'Root=1-5fa9485b-55d15aac140d29b842e5709f'},
#  'json': None,
#  'origin': '118.150.172.83',
#  'url': 'http://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.23.0',
#   'X-Amzn-Trace-Id': 'Root=1-5fa9485d-711d87d86346d6b426cee2e9'},
#  'json': None,
#  'origin': '118.150.172.83',
#  'url': 'http://httpbin.org/post'}

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
